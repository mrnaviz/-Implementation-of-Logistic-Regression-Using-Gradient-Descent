# %% [markdown]
# <a href="https://colab.research.google.com/github/mrnaviz/-Implementation-of-Logistic-Regression-Using-Gradient-Descent/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6. a. Implement any three feature Scaling process using any one of the data set

# %%
import pandas as pd
from scipy import stats
import numpy as np

df=pd.read_csv("bmi.csv")
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.dropna()
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
max_height = df['Height'].max()
max_weight = df['Weight'].max()

print("Maximum Height:",max_height)
print("Maximum Weight:",max_weight)
# Out:
# Maximum Height: 199
# Maximum Weight: 160

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Height', 'Weight']] = scaler.fit_transform(df[['Height', 'Weight']])
df.head()
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.576271  0.418182      4
# 1    Male  0.830508  0.336364      2
# 2  Female  0.762712  0.545455      4
# 3  Female  0.932203  0.490909      3
# 4    Male  0.152542  0.100000      3

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['Height', 'Weight']] = scaler.fit_transform(df[['Height', 'Weight']])
df.head()
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.247939 -0.309117      4
# 1    Male  1.164872 -0.587322      2
# 2  Female  0.920357  0.123647      4
# 3  Female  1.531645 -0.061823      3
# 4    Male -1.280283 -1.391027      3

# %%
from sklearn.preprocessing import Normalizer

scaler = Normalizer()
df[['Height', 'Weight']] = scaler.fit_transform(df[['Height', 'Weight']])
df.head()
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.625687 -0.780074      4
# 1    Male  0.892924 -0.450208      2
# 2  Female  0.991096  0.133150      4
# 3  Female  0.999186 -0.040331      3
# 4    Male -0.677211 -0.735789      3

# %%
#Perform MaxAbsScaler

from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
df[['Height', 'Weight']] = scaler.fit_transform(df[['Height', 'Weight']])
df.head()
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.625687 -0.780076      4
# 1    Male  0.892924 -0.450208      2
# 2  Female  0.991096  0.133151      4
# 3  Female  0.999186 -0.040331      3
# 4    Male -0.677211 -0.735791      3

# %% [markdown]
#  b. i. Create a box plot using mat plot lib

# %%
import matplotlib.pyplot as plt
data = [7, 8, 5, 6, 10, 9, 12, 5, 6, 8]
plt.boxplot(data)
plt.title("Simple Box Plot")
plt.ylabel("Values")
plt.show()

# %% [markdown]
#  ii. Create a KDE plot using seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = [1,2,3,4,5]
sns.kdeplot(data, fill=True)
plt.title("Simple KDE Plot")
plt.xlabel("Values")
plt.show()
